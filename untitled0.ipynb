# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriellineumann/Palavra-chave-/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 1

# %%
print("I competição de programação dá Start")
ano = "II"
print(ano, "competição de programação da Start")
print(f"{ano} competição de programação da Start")
# Out:
# I competição de programação dá Start
# II competição de programação da Start
# II competição de programação da Start

# %% [markdown]
# Aula 2

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24

# %% [markdown]
# #**Aula** 3 ✈ ⚛ 🍫

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
numero_de_professores= 8
if numero_de_alunos + numero_de_monitores+numero_de_professores <= 50:
  resposta_positiva = "pode ir"
resposta_negativa = "não pode ir"
if numero_de_alunos + numero_de_monitores+numero_de_professores <= 50:
   print(resposta_positiva)
else:
   print(resposta_negativa)
# Out:
# Digite a quantidade de alunos: 30
# Digite a quantidade de monitores: 20
# não pode ir
